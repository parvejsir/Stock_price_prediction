# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# !pip install yfinance
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 3.0/3.0 MB 35.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 28.6 MB/s eta 0:00:00
# ...
# Using cached websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# ...
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139097 sha256=a2204b61003751331b4de23adaa3aa7540ceca9e0426814005993ce6361561a8
# ...

# %%
import yfinance as yf
import datetime as dt

stock = "TATAMOTORS.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2025, 6, 25)

df = yf.download(stock, start, end)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11568\3334820902.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price              Close          High           Low          Open  \
# Ticker     TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# Date
# 2000-01-03     40.911037     41.005413     39.146249     39.146249
# 2000-01-04     39.297245     41.335719     38.881999     40.958222
# 2000-01-05     40.250423     41.109223     36.617029     36.617029
# 2000-01-06     41.920837     43.393066     40.580726     40.580726
# 2000-01-07     45.280540     45.280540     42.109581     42.279456
#
# Price             Volume
# Ticker     TATAMOTORS.NS
# Date
# 2000-01-03       3528277
# 2000-01-04       3544397
# 2000-01-05       5849540
# 2000-01-06      10274966
# 2000-01-07      11477451

# %%
df.shape
# Out:
# (6358, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6358 entries, 2000-01-03 to 2025-06-24
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Close, TATAMOTORS.NS)   6358 non-null   float64
#  1   (High, TATAMOTORS.NS)    6358 non-null   float64
#  2   (Low, TATAMOTORS.NS)     6358 non-null   float64
#  3   (Open, TATAMOTORS.NS)    6358 non-null   float64
#  4   (Volume, TATAMOTORS.NS)  6358 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 298.0 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   TATAMOTORS.NS    0
# High    TATAMOTORS.NS    0
# Low     TATAMOTORS.NS    0
# Open    TATAMOTORS.NS    0
# Volume  TATAMOTORS.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price          Close          High           Low          Open        Volume
# Ticker TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# count    6358.000000   6358.000000   6358.000000   6358.000000  6.358000e+03
# mean      256.400479    260.441763    252.687145    256.850521  1.633930e+07
# std       221.276582    224.011054    218.875979    221.781194  2.102922e+07
# min        11.098357     11.456978     10.862423     10.947359  0.000000e+00
# 25%        85.377605     87.408995     83.051297     85.313900  6.180689e+06
# 50%       177.693085    181.457169    174.875730    178.708894  1.019776e+07
# 75%       397.860397    403.884364    392.664756    398.366423  1.795721e+07
# max      1151.945801   1168.949630   1135.536938   1157.051852  3.905778e+08

# %%
df = df.reset_index()

# %%
df.tail()
# Out:
# Price        Date         Close          High           Low          Open  \
# Ticker            TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# 6353   2025-06-18    670.250000    679.349976    668.000000    671.849976
# 6354   2025-06-19    672.299988    676.299988    666.650024    670.250000
# 6355   2025-06-20    676.200012    678.799988    670.099976    673.400024
# 6356   2025-06-23    671.250000    676.000000    666.099976    670.000000
# 6357   2025-06-24    673.650024    686.500000    672.000000    678.000000
#
# Price         Volume
# Ticker TATAMOTORS.NS
# 6353        12556088
# 6354        10895470
# 6355        11393470
# 6356        10265601
# 6357        15359947

# %%
df.columns
# Out:
# MultiIndex([(  'Date',              ''),
#             ( 'Close', 'TATAMOTORS.NS'),
#             (  'High', 'TATAMOTORS.NS'),
#             (   'Low', 'TATAMOTORS.NS'),
#             (  'Open', 'TATAMOTORS.NS'),
#             ('Volume', 'TATAMOTORS.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("tatamotors.csv")

# %%
data01 = pd.read_csv("tatamotors.csv")

# %%
data01.head()
# Out:
#     Price        Date               Close               High  \
# 0  Ticker         NaN       TATAMOTORS.NS      TATAMOTORS.NS
# 1       0  2000-01-03   40.91103744506836   41.0054134700514
# 2       1  2000-01-04  39.297245025634766  41.33571891762288
# 3       2  2000-01-05  40.250423431396484  41.10922345302223
# 4       3  2000-01-06   41.92083740234375  43.39306648376146
#
#                   Low                Open         Volume
# 0       TATAMOTORS.NS       TATAMOTORS.NS  TATAMOTORS.NS
# 1   39.14624936264102   39.14624936264102        3528277
# 2  38.881998813179095     40.958222360845        3544397
# 3  36.617029186740396  36.617029186740396        5849540
# 4  40.580726482046245  40.580726482046245       10274966

# %%
# Candlesticks 
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'], 
                                    high = data01['High'],
                                    low = data01['Low'], 
                                    close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=True)
fig.show()

# %%
df = df.drop(['Date'], axis = 1)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11568\1002300862.py:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.head()
# Out:
# Price          Close          High           Low          Open        Volume
# Ticker TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS TATAMOTORS.NS
# 0          40.911037     41.005413     39.146249     39.146249       3528277
# 1          39.297245     41.335719     38.881999     40.958222       3544397
# 2          40.250423     41.109223     36.617029     36.617029       5849540
# 3          41.920837     43.393066     40.580726     40.580726      10274966
# 4          45.280540     45.280540     42.109581     42.279456      11477451

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)

for i in range(len(temp_data) - 5 + 1):
    window = temp_data[i:i+5]
    avg = sum(window)/5
    print(f"Average of {window} is {avg}")
# Out:
# 50.0
# Average of [10, 20, 30, 40, 50] is 30.0
# Average of [20, 30, 40, 50, 60] is 40.0
# Average of [30, 40, 50, 60, 70] is 50.0
# Average of [40, 50, 60, 70, 80] is 60.0
# Average of [50, 60, 70, 80, 90] is 70.0

# %%
ma100 = df.Close.rolling(100).mean() #moving average of last 100 days window based on closing price
ma100
# Out:
# Ticker  TATAMOTORS.NS
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 6353       677.213975
# 6354       676.572791
# 6355       675.873938
# 6356       675.308017
# 6357       674.974802
#
# [6358 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean() #exp moving avg   EMA_today = α * Price_today + (1 - α) * EMA_yesterday

# %%
ema100
# Out:
# Ticker  TATAMOTORS.NS
# 0           40.911037
# 1           40.879081
# 2           40.866632
# 3           40.887508
# 4           40.974499
# ...               ...
# 6353       703.203703
# 6354       702.591748
# 6355       702.069139
# 6356       701.458859
# 6357       700.908189
#
# [6358 rows x 1 columns]

# %%
ema200 = df['Close'].ewm(span=200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (4450, 1)

# %%
data_testing.shape
# Out:
# (1908, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.05157571],
#        [0.04878386],
#        [0.05043285],
#        ...,
#        [0.67101479],
#        [0.66504846],
#        [0.66521899]])

# %%
data_training_array.shape
# Out:
# (4450, 1)

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (4350, 100, 1)

# %%
# Model Building
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()

model.add(Bidirectional(LSTM(units=64, activation='tanh', return_sequences=True), input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(Bidirectional(LSTM(units=96, activation='tanh', return_sequences=True)))
model.add(Dropout(0.25))

model.add(Bidirectional(LSTM(units=128, activation='tanh')))
model.add(Dropout(0.3))

model.add(Dense(units=1))
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_3 (Bidirectional)      │ (None, 100, 128)            │          33,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 100, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_4 (Bidirectional)      │ (None, 100, 192)            │         172,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 100, 192)            │               0 │
# ...

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Optional callbacks to avoid overfitting
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

history =model.fit(
    x_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop, checkpoint],
    verbose=1  
)
# Out:
# Epoch 1/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 65s 512ms/step - loss: 0.0084 - val_loss: 0.0029
# Epoch 2/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 68s 630ms/step - loss: 6.8067e-04 - val_loss: 0.0013
# Epoch 3/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 70s 643ms/step - loss: 5.0893e-04 - val_loss: 0.0013
# Epoch 4/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 75s 689ms/step - loss: 5.0349e-04 - val_loss: 0.0028
# Epoch 5/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 67s 615ms/step - loss: 5.4272e-04 - val_loss: 0.0011
# Epoch 6/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 69s 635ms/step - loss: 4.3942e-04 - val_loss: 9.7127e-04
# Epoch 7/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 66s 608ms/step - loss: 3.6151e-04 - val_loss: 0.0021
# Epoch 8/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 69s 636ms/step - loss: 4.5313e-04 - val_loss: 8.3845e-04
# Epoch 9/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 66s 606ms/step - loss: 4.2321e-04 - val_loss: 9.5910e-04
# Epoch 10/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 69s 636ms/step - loss: 4.3038e-04 - val_loss: 0.0015
# ...

# %%
past_100_days = data_training.tail(100)

# %%
past_100_days
# Out:
# Ticker  TATAMOTORS.NS
# 4350       425.968597
# 4351       421.189667
# 4352       424.539886
# 4353       425.574463
# 4354       430.846100
# ...               ...
# 4445       402.221619
# 4446       405.226898
# 4447       398.969910
# 4448       395.521149
# 4449       395.619720
#
# [100 rows x 1 columns]

# %%
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.shape
# Out:
# (2008, 1)

# %%
data_testing.shape
# Out:
# (1908, 1)

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1908, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 7s 95ms/step

# %%
y_predicted.shape
# Out:
# (1908, 1)

# %%
scaler.scale_
# Out:
# array([0.00091945])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# %%
mae = mean_absolute_error(y_test, y_predicted)
print("MAE:", mae)
mse = mean_squared_error(y_test, y_predicted)
print("MSE:", mse)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
r2 = r2_score(y_test, y_predicted)
print("R2 Score:", r2)
# Out:
# MAE: 2.5014060532979423
# MSE: 13.24235058258165
# RMSE: 3.63900406465583
# R2 Score: 0.9971420701527355

# %%
model.save('stock_dl_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
